# %%
import pyodbc
import pandas as pd
pyodbc.drivers()
# Out:
# ['ODBC Driver 17 for SQL Server']

# %%
from Database_Connection_Classes import ConnFifa as dfc
from Database_Connection_Classes import Connection as dfc2

# %%
df = dfc().df_creator()

# %%
type(df)

# %%
from Data_Cleaning import CleanFifa as dc

df_fifa = dc().fetcher()

# %%
df_fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15926 entries, 0 to 18206
# Data columns (total 83 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Counter                   15926 non-null  int64
#  1   ID                        15926 non-null  int64
#  2   Name                      15926 non-null  object
#  3   Age                       15926 non-null  int64
#  4   Nationality               15926 non-null  object
#  5   Overall                   15926 non-null  int64
#  6   Potential                 15926 non-null  int64
#  7   Club                      15926 non-null  object
#  8   Value                     15926 non-null  float64
#  9   Wage                      15926 non-null  float64
#  10  Special                   15926 non-null  int64
#  11  Preferred_Foot            15926 non-null  object
#  12  International_Reputation  15926 non-null  float64
# ...
